# %% [markdown]
# # Introduction
# Dear students,
#
# well done for performing these somewhat cumbersone installation steps. You now are now inside of a Jupyter Notebook. The text you are reading is written in Markdown and the field below is for Python code to be executed. We suggest that you read everything carefully and to not treat this bonus lab as something you need to finish up but as a chance to learn cutting edge techniques for plotting, analysing and reporting by combining Markdown, Python and GIS. The whole course is indended to providing you with a skill set and a starting point to explore in what ways these coding skills can benefit your own future research. As you probably have heard a million times, coding is there to make your life easier even though the slightly steep learning curve may mask this fact. With proper coding skills you will be able to provide much more sophisticated analyses in much short time, especially if the same set of analyses occur repeatedly.
#
# ## General Info about Jupyter Notebooks
#
# The Jupyter Notebook is an incredibly powerful tool for interactively developing and presenting data science projects.
#
# First, though: what is a “notebook”? A notebook integrates code and its output into a single document that combines visualizations, narrative text, mathematical equations, and other rich media. This intuitive workflow promotes iterative and rapid development, making notebooks an increasingly popular choice at the heart of contemporary data science, analysis, and increasingly science at large.
#
# Be aware that the dashboard will give you access only to the files and sub-folders contained within Jupyter’s start-up directory; however, the start-up directory can be changed. It is also possible to start the dashboard on any system via the command prompt (or terminal on Unix systems) by entering the command jupyter notebook; in this case, the current working directory will be the start-up directory.
#
# The astute reader may have noticed that the URL for the dashboard is something like http://localhost:8888/tree. Localhost is not a website, but indicates that the content is being served from your local machine: your own computer. Jupyter’s Notebooks and dashboard are web apps, and Jupyter starts up a local Python server to serve these apps to your web browser, making it essentially platform independent and opening the door to easier sharing on the web.
#
# It will be useful to understand what this file really is. Each .ipynb file is a text file that describes the contents of your notebook in a format called JSON. Each cell and its contents, including image attachments that have been converted into strings of text, is listed therein along with some metadata. You can edit this yourself — if you know what you are doing! — by selecting “Edit > Edit Notebook Metadata” from the menu bar in the notebook.
#
# You can also view the contents of your notebook files by selecting “Edit” from the controls on the dashboard, but the keyword here is “can“; there’s no reason other than curiosity to do so unless you really know what you are doing.
#
# Now that you have an open notebook in front of you, its interface will hopefully not look entirely alien; after all, Jupyter is essentially just an advanced word processor. Why not take a look around? Check out the menus to get a feel for it, especially take a few moments to scroll down the list of commands in the command palette, which is the small button with the keyboard icon (or Ctrl + Shift + P).
#
# There are two fairly prominent terms that you should notice, which are probably new to you: cells and kernels are key both to understanding Jupyter and to what makes it more than just a word processor. Fortunately, these concepts are not difficult to understand.
#
# - A kernel is a “computational engine” that executes the code contained in a notebook document.
# - A cell is a container for text to be displayed in the notebook or code to be executed by the notebook’s kernel.
#
# You may have noticed that Jupyter gives you the option to change kernel, and in fact there are many different options to choose from. Back when you created a new notebook from the dashboard by selecting a Python version, you were actually choosing which kernel to use.
#
# Not only are there kernels for different versions of Python, but also for over 100 languages including Java, C, and even Fortran. Data scientists may be particularly interested in the kernels for R and Julia, as well as both imatlab and the Calysto MATLAB Kernel for Matlab. The SoS kernel provides multi-language support within a single notebook. Each kernel has its own installation instructions, but will likely require you to run some commands on your computer.
#
# # Use of Jupyter Notebooks
#
# When you create a new cell using the "+" button you need to tell Jupyter whether this is supposed to be a Markdown field or a code field. This can be done and changed at any time using the dropdown menue.
#
# **We ask you to save this Jupyter Notebook under a different name like e.g. "Jupyter_Notebook_with_yourname". This has two reasons. 1) If you somehow "mess up" the code you can easily start from scratch by loading the original file and 2) This way you can easily show your progress on this notebook by sending the .ipynb file.**
#
# ## A few pointers for Markdown
#
# You can make text *italic* or **bold** by surrounding a block of text with a single or double * respectively
#
# You can add headings by starting a line with one (or multiple) # followed by a space, as in the following example:
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
#
# You can create bullet point by starting your line of text with a "-" followed by a space like in this nice list of three items
# - Item 1
# - Item 2
# - Item 3
#
# You can also include neat Latex equations:
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$
#
# Double click on this text to see the Markdowncode. To see the Markdown in its compiles form you also have to click on "Run" like with any other code snippet.
#
# # A few pointers for Python Coding
# - Execute code in the code fields by clicking on the button that looks like the "play next song"
# - It is imparative that you execute each code snippet in order because they build on each other. If an error message for one code snippet occurred it means in most cases that this operation was not successful and that all code snippets that build on the previous one will either also create error messages or will do unexpected things
# - You will find that many code snippets are complete and executable. But you will also see either empty fields or placeholder like "---" where we ask you to complete the code using either resources we provided in this notebook, in one of your previous labs or where we ask you to google it. This is a very good habit when learning to code since there will always be someone who had the same/similar problem that you have and already found a solution
# - The syntax may differ slightly between your previous work with Python 2 and your current work with Python 3. These differences are easy to correct and there is a ton of resources available for you. Here two webpages that explains the differences quite nicely (https://sebastianraschka.com/Articles/2014_python_2_3_key_diff.html,https://python-future.org/compatible_idioms.html)
#
#
# ## If you should prefer coding in R for your own work
# Make sure you have R installed on your computer. Then as with the previous installations execute this code in Anaconda Prompt to install the R kernel for Jupyter Notebook:
#
# conda install -c r r-irkernel
#
# After the installation to create a new R based (R Markdown) Notebook select in the drop down menue under Notebooks R instead of Python 3
#
# ## Important Final Remarks
# When you are happy with your coding and reporting do export your document as pdf and save it as "Applied_GIS_Bonus_Lab_yourstudentID". You can do it by clicking File/Download as/PDF via LaTeX (.pdf). Be aware that the document will be compiled and vonverted which may take a few minutes.
#
# # Warming up to Python Coding in Jupyter Notebook:

# %% [markdown]
# Load necessary modules.

# %%
import pylab as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Create a list with values from 0 to 3 with 0.01 intervals.

# %%
t=np.arange(0.0,3,0.01)

# %% [markdown]
# Calculate the sine curve for the values within t.

# %%
s=np.sin(np.pi*t)

# %% [markdown]
# Plot the data and add axis and title labels.

# %%
pl.plot(t,s)
pl.xlabel("X-Axis")
pl.ylabel("Y-Axis")
pl.title("Sine Plot")
# Out:
# Text(0.5, 1.0, 'Sine Plot')

# %% [markdown]
# Now we ask you to load some external csv file, to provide a quick glance at the dataframe and to store the column called "BP" as x variable and the column called "Temperature_C" as y-variable.

# %%
df = pd.read_csv(r'C:\Jupyter\Gisp2_cleaned.csv') 
print (df)
#Store each column as separate variable
x=df['BP']
y=df['Temperature_C']
# Out:
#               BP  Temperature_C
# 0       -95.1409       -31.5913
# 1      -107.1300       -31.6220
# 2      -113.1490       -31.6026
# 3      -119.2050       -31.6002
# 4      -119.2050       -31.5980
# ...          ...            ...
# 1627 -49746.0000       -40.5505
# 1628 -49806.0000       -40.2651
# 1629 -49868.0000       -40.1018
# 1630 -49922.0000       -39.8165
# 1631 -49981.0000       -39.9694
#
# [1632 rows x 2 columns]

# %% [markdown]
# Define the figure size to be 10 wide and 8 long. Change the tick label size to 20 and the axis label size to 25. Choose for title the font size 24 and make it bold.

# %%
pl.figure(figsize=(10,8))
pl.rc('xtick', labelsize=20)
pl.rc('ytick', labelsize=20)
pl.plot(x,y)
pl.xlabel("Age (BP)",fontsize=25)
pl.ylabel("Temperature (°C)",fontsize=25)
pl.title("GISP2 Ice Core - Reconstructed Greenland Temperature",fontsize=24,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'GISP2 Ice Core Reconstructed Greenland Temperature')

# %% [markdown]
# Change the x and y axis scale to only show the Holocene (last 11,700 years) and save figure.

# %%
pl.figure(figsize=(10,8))
pl.rc('xtick', labelsize=20)
pl.rc('ytick', labelsize=20)
pl.plot(x,y)
pl.xlim(-11700,0)
pl.ylim(-40,-28)
pl.xlabel("Age (BP)",fontsize=25)
pl.ylabel("Temperature (°C)",fontsize=25)
pl.title(u"GISP2 Ice Core - Reconstructed Greenland\n Temperature for the Holocene",fontsize=24,fontweight="bold")
pl.savefig("GISP2 Holocene.png",dpi=600)

# %% [markdown]
# When we load a figure from the McMichael et. al 2012 paper "Insights from past millennia into climatic impacts on human health and survival" using an url, we see that the Holocene is actually not as stable as we previously thought. We see that even relative small Holocene climate fluctuations had a strong impact on civilisations. Please be aware that the time scales differ between GISP2 figure and PNAS aticle. So 10,000 BCE is roughly 8,000 BP (BP defined as 1950 CE). We can also add pictures in our report by clicking "Edit" and then "Insert Image".

# %%
from IPython.display import Image
Image(url= "https://www.pnas.org/content/pnas/109/13/4730/F1.large.jpg", width=1000, height=1000)
# Out:
# <img src="https://www.pnas.org/content/pnas/109/13/4730/F1.large.jpg" width="1000" height="1000"/>

# %% [markdown]
# # Shifting Gears by working with GIS via ipyleaflet

# %% [markdown]
# We are now "warmed up" and learned/recaptured how to
# - create a report like structure with Markdown
# - plot simple sine data
# - read a csv and to store columns as x and as y variables
# - create a plot with more modifications according to our needs
# - change axis range for focussing on a specific interval
# - load an external image file
#
# Let's shift up gear and include some GIS with ipyleaflet.
#
# ipyleaflet is a Jupyter - LeafletJS bridge, bringing mapping capabilities to the notebook and JupyterLab.
# Built as a bridge between the LeafletJS package and Jupyter, the ipyleaflet API maps to that of LeafletJS, bringing most of the core features of the package to Jupyter, and enabling a few popular LeafletJS extensions. A small difference is that following the Python coding style, ipyleaflet makes use of snake_case instead of CamelCase for attribute names.
# ipyleaflet features
# The main components to the library are layers and controls, respectively items to be displayed on the map, and interactive widgets overlayed on the map area for greater interactivity.
#
#
#
# First start by looking at some basemaps:

# %% [markdown]
# ## Basemaps

# %%
from ipyleaflet import Map, basemaps

center = [38.128, 2.588]
zoom = 5

Map(basemap=basemaps.OpenStreetMap.Mapnik, center=center, zoom=zoom)
# Out:
# Map(center=[38.128, 2.588], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_…

# %%
Map(basemap=basemaps.OpenTopoMap, center=center, zoom=zoom)
# Out:
# Map(center=[38.128, 2.588], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_…

# %%
Map(basemap=basemaps.Esri.WorldImagery, center=center, zoom=zoom)
# Out:
# Map(center=[38.128, 2.588], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_…

# %%
Map(basemap=basemaps.CartoDB.Positron, center=center, zoom=zoom)
# Out:
# Map(center=[38.128, 2.588], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_…

# %% [markdown]
# Look at https://ipyleaflet.readthedocs.io/en/latest/api_reference/basemaps.html for more base maps.

# %% [markdown]
# ## Marker

# %% [markdown]
# We can set a marker like this:

# %%
from ipyleaflet import Map, Marker

center = (52.204793, 360.121558)

m = Map(center=center, zoom=15)

marker = Marker(location=center, draggable=False)
m.add_layer(marker);

m
# Out:
# Map(center=[52.204793, 360.121558], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# Or like this:

# %%
from ipyleaflet import AwesomeIcon, Marker, Map

center = (38.91342738235981, -77.03912909142674)

icon1 = AwesomeIcon(
    name='bus',
    marker_color='red',
    icon_color='black',
    spin=False
)

marker1 = Marker(icon=icon1, location=(center[0], center[1] - 0.05))

icon2 = AwesomeIcon(
    name='gear',
    marker_color='green',
    icon_color='darkgreen',
    spin=True
)

marker2 = Marker(icon=icon2, location=(center[0], center[1] + 0.05))

m = Map(center=center, zoom=13)

m.add_layer(marker1)
m.add_layer(marker2)

m
# Out:
# Map(center=[38.91342738235981, -77.03912909142674], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
Or like this:

# %%
from ipyleaflet import Map, Marker, MarkerCluster

m = Map(center=(50, 0), zoom=5)

marker1 = Marker(location=(48, -2))
marker2 = Marker(location=(50, 0))
marker3 = Marker(location=(52, 2))

marker_cluster = MarkerCluster(
    markers=(marker1, marker2, marker3)
)

m.add_layer(marker_cluster);

m
# Out:
# Map(center=[50, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# Look at
# https://ipyleaflet.readthedocs.io/en/latest/api_reference/marker.html
# https://ipyleaflet.readthedocs.io/en/latest/api_reference/awesome_icon.html
# https://ipyleaflet.readthedocs.io/en/latest/api_reference/marker_cluster.html
# for further references on how to use these features.

# %% [markdown]
# ## Heatmaps

# %%
from ipyleaflet import Map, Heatmap
from random import uniform
m = Map(center=(0, 0), zoom=2)

heatmap = Heatmap(
    locations=[[uniform(-80, 80), uniform(-180, 180), uniform(0, 1000)] for i in range(1000)],
    radius=20
)

m.add_layer(heatmap);

m
# Out:
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…

# %% [markdown]
# For more info: https://ipyleaflet.readthedocs.io/en/latest/api_reference/heatmap.html

# %% [markdown]
# ## Chloropleths

# %%
import ipyleaflet
import json
import pandas as pd
import os
import requests
from ipywidgets import link, FloatSlider
from branca.colormap import linear

def load_data(url, filename, file_type):
    r = requests.get(url)
    with open(filename, 'w') as f:
        f.write(r.content.decode("utf-8"))
    with open(filename, 'r') as f:
        return file_type(f)

geo_json_data = load_data(
    'https://raw.githubusercontent.com/jupyter-widgets/ipyleaflet/master/examples/us-states.json',
    'us-states.json',
     json.load)

unemployment = load_data(
    'https://raw.githubusercontent.com/jupyter-widgets/ipyleaflet/master/examples/US_Unemployment_Oct2012.csv',
    'US_Unemployment_Oct2012.csv',
     pd.read_csv)

unemployment =  dict(zip(unemployment['State'].tolist(), unemployment['Unemployment'].tolist()))

layer = ipyleaflet.Choropleth(
    geo_data=geo_json_data,
    choro_data=unemployment,
    colormap=linear.YlOrRd_04,
    border_color='black',
    style={'fillOpacity': 0.8, 'dashArray': '5, 5'})

m = ipyleaflet.Map(center = (43,-100), zoom = 4)
m.add_layer(layer)
m
# Out:
# Map(center=[43, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# For more info: https://ipyleaflet.readthedocs.io/en/latest/api_reference/choropleth.html

# %% [markdown]
# ## Split map control

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, SplitMapControl

m = Map(center=(42.6824, 365.581), zoom=5)

right_layer = basemap_to_tiles(basemaps.NASAGIBS.ModisTerraTrueColorCR, "2017-11-11")
left_layer = basemap_to_tiles(basemaps.NASAGIBS.ModisAquaBands721CR, "2017-11-11")

control = SplitMapControl(left_layer=left_layer, right_layer=right_layer)
m.add_control(control)

m
# Out:
# Map(center=[42.6824, 365.581], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %% [markdown]
# ## Example Wind Velocity

# %%
from ipyleaflet import Map, Velocity, TileLayer, basemaps
import xarray as xr

# %%
center = [44.33956524809713, -130.60546875000003]
zoom = 3
m = Map(center=center, zoom=zoom, interpolation='nearest', basemap=basemaps.CartoDB.DarkMatter)
m
# Out:
# Map(center=[44.33956524809713, -130.60546875000003], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
import os

if not os.path.exists('wind-global.nc'):
    url = 'https://github.com/benbovy/xvelmap/raw/master/notebooks/wind-global.nc'
    import requests
    r = requests.get(url)
    wind_data = r.content
    with open('wind-global.nc', 'wb') as f:
        f.write(wind_data)

# %%
ds = xr.open_dataset('wind-global.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 181, lon: 360)
# Coordinates:
#   * lat      (lat) float64 90.0 89.0 88.0 87.0 86.0 ... -87.0 -88.0 -89.0 -90.0
#   * lon      (lon) float64 0.0 1.0 2.0 3.0 4.0 ... 355.0 356.0 357.0 358.0 359.0
# Data variables:
#     u_wind   (lat, lon) float64 ...
#     v_wind   (lat, lon) float64 ...
# Attributes:
#     centerName:      US National Weather Service - NCEP(WMC)
#     disciplineName:  Meteorological products
#     refTime:         2016-04-30T06:00:00.000Z

# %%
display_options = {
    'velocityType': 'Global Wind',
    'displayPosition': 'bottomleft',
    'displayEmptyString': 'No wind data'
}
wind = Velocity(
    data=ds, 
    zonal_speed='u_wind', meridional_speed='v_wind', 
    latitude_dimension='lat', longitude_dimension='lon', 
    velocity_scale=0.01, max_velocity=20, 
    display_options=display_options
)
m.add_layer(wind)

# %% [markdown]
# # End of Tutorial
# We hope you enjoyed this lab and feel inclined to use Python in your future research activities.

# %% [markdown]
# # Optional: GeoPandas
# For those of you who want a bit more flexibility we recommend GeoPandas. The installation is similar to the installations we did at the beginning in Anaconda Prompt.
#
# ## Installation
# Here is how to install it in Anaconda Prompt:
#
# *conda install --channel conda-forge geopandas*
#
# You will need to restart Jupyter Notebook after installation
#
# ## Creating a new environment
# Creating a new environment is not strictly necessary, but given that installing other geospatial packages from different channels may cause dependency conflicts (as mentioned in the note above), it can be good practice to install the geospatial stack in a clean environment starting fresh.
#
# The following commands create a new environment with the name geo_env, configures it to install packages always from conda-forge, and installs GeoPandas in it:
#
# *conda create -n geo_env*
#
# *conda activate geo_env*
#
# *conda config --env --add channels conda-forge*
#
# *conda config --env --set channel_priority strict*
#
# *conda install python=3 geopandas*
#
# **Now you are ready to go and work through the optional Jupyter Notebooks you will find in the subfolder "Optional Jupyter notebooks to use after Installation of GeoPandas"**
#
# You will find additional help at:
#
# https://geopandas.org/
